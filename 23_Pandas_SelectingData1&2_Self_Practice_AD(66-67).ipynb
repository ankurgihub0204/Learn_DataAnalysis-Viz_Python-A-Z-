# %%
#Selecting Data (1&2)

#pd.read_csv('filename.csv')
#iloc & loc
#countries_data[(countries_data['Region']=='Asia') & (countries_data['Population']>300,000,000)] --and
#countries_data[(countries_data['Region']=='Asia') | (countries_data['Population']>300,000,000)] --or
#DataFrame isin([list_of_values])
#DataFrame.head()
#DataFrame.tail()

# %%
import pandas as pd

# %%
countries_data=pd.read_csv('top_10_countries.csv')

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
countries_data.columns
# Out:
# Index(['Rank', 'Country / Dependency', 'Region', 'Population', '% of world',
#        'Date'],
#       dtype='object')

# %%
#to get the values from single column

# %%
countries_data['Region']
# Out:
# 0        Asia
# 1        Asia
# 2    Americas
# 3        Asia
# 4        Asia
# 5    Americas
# 6      Africa
# 7        Asia
# 8      Europe
# 9    Americas
# Name: Region, dtype: object

# %%
type(countries_data['Region']) #so as you can see below, single column pulled from dataframe is actually a series
# Out:
# pandas.core.series.Series

# %%
#to get the distinct values from single column

# %%
countries_data['Region'].unique()
# Out:
# array(['Asia', 'Americas', 'Africa', 'Europe'], dtype=object)

# %%
#to get the distinct values from multiple column

# %%
countries_data[['Rank', 'Country / Dependency', 'Region', 'Population']]
# Out:
#    Rank Country / Dependency    Region        Population
# 0     1                China      Asia  1,412,600,000.00
# 1     2                India      Asia  1,386,946,912.00
# 2     3        United States  Americas    333,073,186.00
# 3     4            Indonesia      Asia    271,350,000.00
# 4     5             Pakistan      Asia    225,200,000.00
# 5     6               Brazil  Americas    214,231,641.00
# 6     7              Nigeria    Africa    211,401,000.00
# 7     8           Bangladesh      Asia    172,062,576.00
# 8     9               Russia    Europe    146,171,015.00
# 9    10               Mexico  Americas    126,014,024.00

# %%
#if we want to change the order, type the list in that order, example:

# %%
countries_data[['Region', 'Country / Dependency', 'Rank']]
# Out:
#      Region Country / Dependency  Rank
# 0      Asia                China     1
# 1      Asia                India     2
# 2  Americas        United States     3
# 3      Asia            Indonesia     4
# 4      Asia             Pakistan     5
# 5  Americas               Brazil     6
# 6    Africa              Nigeria     7
# 7      Asia           Bangladesh     8
# 8    Europe               Russia     9
# 9  Americas               Mexico    10

# %%
#slicing te DataFrame using iloc & loc

#just like the lists they take (start, stop, step) in (rows,columns) syntax,just like the numpy arrays:

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
countries_data.iloc[3] #returns index postion 3, which is the fourthe row of DF
# Out:
# Rank                                 4
# Country / Dependency         Indonesia
# Region                            Asia
# Population              271,350,000.00
# % of world                       3.42%
# Date                         31-Dec-20
# Name: 3, dtype: object

# %%
#if we want all data from row 4 & below

# %%
countries_data.iloc[3:]
# Out:
#    Rank Country / Dependency    Region      Population % of world       Date
# 3     4            Indonesia      Asia  271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia  225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas  214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa  211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia  172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe  146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas  126,014,024.00      1.59%   2-Mar-20

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
#reversing the data (step size of -1)

# %%
countries_data[::-1]
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
#how about population value of US

# %%
countries_data.iloc[2,3]
# Out:
# '333,073,186.00'

# %%
#row (2 & below) and column 1 upto & including column index 3

# %%
countries_data.iloc[2:,1:4]
# Out:
#   Country / Dependency    Region      Population
# 2        United States  Americas  333,073,186.00
# 3            Indonesia      Asia  271,350,000.00
# 4             Pakistan      Asia  225,200,000.00
# 5               Brazil  Americas  214,231,641.00
# 6              Nigeria    Africa  211,401,000.00
# 7           Bangladesh      Asia  172,062,576.00
# 8               Russia    Europe  146,171,015.00
# 9               Mexico  Americas  126,014,024.00

# %%
#loc, is similar to this, but looks more meaning full, as there you mention the columns name instead of index #

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
countries_data.loc[2, 'Country / Dependency']
# Out:
# '\xa0United States'

# %%
# so here you give the index number for row, but for column povide column values/names

# %%
countries_data.loc[2:7,'Rank':'Population'] #so 2:7, includes 2nd & 7th row too, hmm...
# Out:
#    Rank Country / Dependency    Region      Population
# 2     3        United States  Americas  333,073,186.00
# 3     4            Indonesia      Asia  271,350,000.00
# 4     5             Pakistan      Asia  225,200,000.00
# 5     6               Brazil  Americas  214,231,641.00
# 6     7              Nigeria    Africa  211,401,000.00
# 7     8           Bangladesh      Asia  172,062,576.00

# %%
countries_data.loc[2,'Country / Dependency':] #so 2 we get row with index= 2, & columns starting countries/depend onwards...
# Out:
# Country / Dependency     United States
# Region                        Americas
# Population              333,073,186.00
# % of world                       4.20%
# Date                         18-Jan-22
# Name: 2, dtype: object

# %%
countries_data.loc[0:,'Country / Dependency':] #so 0: means all the rows, but columns starting countries/depend onwards...
# Out:
#   Country / Dependency    Region        Population % of world       Date
# 0                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
countries_data.loc[2:7,'Country / Dependency':] #so 2:7, includes 2nd & 7th row too, hmm...
# Out:
#   Country / Dependency    Region      Population % of world       Date
# 2        United States  Americas  333,073,186.00      4.20%  18-Jan-22
# 3            Indonesia      Asia  271,350,000.00      3.42%  31-Dec-20
# 4             Pakistan      Asia  225,200,000.00      2.84%   1-Jul-21
# 5               Brazil  Americas  214,231,641.00      2.70%  18-Jan-22
# 6              Nigeria    Africa  211,401,000.00      2.67%   1-Jul-21
# 7           Bangladesh      Asia  172,062,576.00      2.17%  18-Jan-22

# %%
countries_data.loc[2:7,['Country / Dependency', 'Region', 'Population']] #so 2:7 rows with columns as mentioned
# Out:
#   Country / Dependency    Region      Population
# 2        United States  Americas  333,073,186.00
# 3            Indonesia      Asia  271,350,000.00
# 4             Pakistan      Asia  225,200,000.00
# 5               Brazil  Americas  214,231,641.00
# 6              Nigeria    Africa  211,401,000.00
# 7           Bangladesh      Asia  172,062,576.00

# %%
#so this is all about iloc and loc

# %%
#now, lets move to filter the data, lets say we want all rows with Region=Asia

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21
# 5     6               Brazil  Americas    214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa    211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe    146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas    126,014,024.00      1.59%   2-Mar-20

# %%
countries_data=='Asia'
# Out:
#     Rank  Country / Dependency  Region  Population  % of world   Date
# 0  False                 False    True       False       False  False
# 1  False                 False    True       False       False  False
# 2  False                 False   False       False       False  False
# 3  False                 False    True       False       False  False
# 4  False                 False    True       False       False  False
# 5  False                 False   False       False       False  False
# 6  False                 False   False       False       False  False
# 7  False                 False    True       False       False  False
# 8  False                 False   False       False       False  False
# 9  False                 False   False       False       False  False

# %%
#so above it evaluates all elements and returned 'True' where condition was met (ie.e where we get 'Asia')

#so if we pass above condition to data frame, it will return the value 'Asia', wherever it is present

# %%
countries_data[countries_data=='Asia']
# Out:
#    Rank Country / Dependency Region Population % of world Date
# 0   NaN                  NaN   Asia        NaN        NaN  NaN
# 1   NaN                  NaN   Asia        NaN        NaN  NaN
# 2   NaN                  NaN    NaN        NaN        NaN  NaN
# 3   NaN                  NaN   Asia        NaN        NaN  NaN
# 4   NaN                  NaN   Asia        NaN        NaN  NaN
# 5   NaN                  NaN    NaN        NaN        NaN  NaN
# 6   NaN                  NaN    NaN        NaN        NaN  NaN
# 7   NaN                  NaN   Asia        NaN        NaN  NaN
# 8   NaN                  NaN    NaN        NaN        NaN  NaN
# 9   NaN                  NaN    NaN        NaN        NaN  NaN

# %%
#still we did not get what we wanted (we want all the rows with region==asia), lets see how to do that

# %%
countries_data[countries_data['Region']=='Asia']
# Out:
#    Rank Country / Dependency Region        Population % of world       Date
# 0     1                China   Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India   Asia  1,386,946,912.00     17.50%  18-Jan-22
# 3     4            Indonesia   Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan   Asia    225,200,000.00      2.84%   1-Jul-21
# 7     8           Bangladesh   Asia    172,062,576.00      2.17%  18-Jan-22

# %%
countries_data[Population]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 countries_data[Population]
#
# NameError: name 'Population' is not defined

# %%
#cool, now this works, this is how to filter

# %%
#lets say if we want to evaluate multiple conditions (region==asia & population>3 millions)

# %%
countries_data[(countries_data['Region']=='Asia') & (countries_data['Population']>300,000,000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 countries_data[(countries_data['Region']=='Asia') & (countries_data['Population']>300,000,000)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
#cool, we see above error, as population column has a value as 100,000,000 (with ','), but in course material  ...
#....it is a straight number (100000000, instead of 100,000,000)...so object data type, instead of number

# %%
#lets me try to fix it, I will add 1 more population_2 column with clean numbers:

#using apply method (taught in 68th chapter, next to next chapter)

#plan is to multiply each element by 1 & see if that helps, although we can do .astype too, but lets check..

# %%
def multiply_1(x):
    return x*1

# %%
#checking the function

multiply_1(3)
# Out:
# 3

# %%
type(multiply_1(3.0))
# Out:
# float

# %%
countries_data['Population'].apply(multiply_1)
# Out:
# 0    1,412,600,000.00
# 1    1,386,946,912.00
# 2      333,073,186.00
# 3      271,350,000.00
# 4      225,200,000.00
# 5      214,231,641.00
# 6      211,401,000.00
# 7      172,062,576.00
# 8      146,171,015.00
# 9      126,014,024.00
# Name: Population, dtype: object

# %%
#hmm ,it didn't work :(

#lets create a function to replace ',' with ''

# %%
def replace_1 (x):
    return x.replace(',','')

# %%
replace_1('arr,tt')
# Out:
# 'arrtt'

# %%
countries_data['Population'].apply(replace_1)
# Out:
# 0    1412600000.00
# 1    1386946912.00
# 2     333073186.00
# 3     271350000.00
# 4     225200000.00
# 5     214231641.00
# 6     211401000.00
# 7     172062576.00
# 8     146171015.00
# 9     126014024.00
# Name: Population, dtype: object

# %%
#hurray, it worked, but its still object :(

#may be changed it to int (by .astype)

# %%
countries_data['Population'].apply(replace_1).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 countries_data['Population'].apply(replace_1).astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
#yay, but we could have done this earlier too on original population column, lets see (if we could have...)

# %%
countries_data['Population']

# %%
countries_data['Population'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 countries_data['Population'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
#hmm, may be not, so I am awesom....

#we 1st have to remove the ',' and thus write a function for that. Althought we can also apply 'lambda' function...
#... to avoid creating a function

#remember, we are trying to add a new population column with no ',' values

# %%
countries_data['Population'].apply(lambda x: x.replace(',',''))
# Out:
# 0    1412600000.00
# 1    1386946912.00
# 2     333073186.00
# 3     271350000.00
# 4     225200000.00
# 5     214231641.00
# 6     211401000.00
# 7     172062576.00
# 8     146171015.00
# 9     126014024.00
# Name: Population, dtype: object

# %%
# hurray, brilliant.. now lets convert it to int type

# %%
countries_data['Population'].apply(lambda x: x.replace(',','')).astype(float)
# Out:
# 0    1.412600e+09
# 1    1.386947e+09
# 2    3.330732e+08
# 3    2.713500e+08
# 4    2.252000e+08
# 5    2.142316e+08
# 6    2.114010e+08
# 7    1.720626e+08
# 8    1.461710e+08
# 9    1.260140e+08
# Name: Population, dtype: float64

# %%
# cool.. now lets create a column 'Population_2'

# %%
countries_data['Population_2']=countries_data['Population'].apply(lambda x: x.replace(',','')).astype(float)

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world  \
# 0     1                China      Asia  1,412,600,000.00     17.80%
# 1     2                India      Asia  1,386,946,912.00     17.50%
# 2     3        United States  Americas    333,073,186.00      4.20%
# 3     4            Indonesia      Asia    271,350,000.00      3.42%
# 4     5             Pakistan      Asia    225,200,000.00      2.84%
# 5     6               Brazil  Americas    214,231,641.00      2.70%
# 6     7              Nigeria    Africa    211,401,000.00      2.67%
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%
# 8     9               Russia    Europe    146,171,015.00      1.84%
# 9    10               Mexico  Americas    126,014,024.00      1.59%
#
#         Date  Population_2
# 0  31-Dec-21  1.412600e+09
# 1  18-Jan-22  1.386947e+09
# 2  18-Jan-22  3.330732e+08
# 3  31-Dec-20  2.713500e+08
# 4   1-Jul-21  2.252000e+08
# 5  18-Jan-22  2.142316e+08
# ...

# %%
countries_data.dtypes
# Out:
# Rank                      int64
# Country / Dependency     object
# Region                   object
# Population               object
# % of world               object
# Date                     object
# Population_2            float64
# dtype: object

# %%
#cool, so new column is added, but we have to convert it to 'int', instead of 'float'

# %%
countries_data['Population_2'] = countries_data['Population_2'].astype(int)

# %%
countries_data.dtypes
# Out:
# Rank                     int64
# Country / Dependency    object
# Region                  object
# Population              object
# % of world              object
# Date                    object
# Population_2             int32
# dtype: object

# %%
#cool, 'Population_2' is now converted to integer (int)

# now going back to #82, we were trying to filter the DataFrame to region==asia & population>300000000, so lets do it

# %%
countries_data[(countries_data['Region']=='Asia') & (countries_data['Population_2']>300000000)]
# Out:
#    Rank Country / Dependency Region        Population % of world       Date  \
# 0     1                China   Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India   Asia  1,386,946,912.00     17.50%  18-Jan-22
#
#    Population_2
# 0    1412600000
# 1    1386946912

# %%
#ufff, finally, it worked, what we tried to achieve in [87] above

# %%
#lets ,say if we want the rows where either we have region==asia OR population>300000000, then we use or

# %%
countries_data[(countries_data['Region']=='Asia') or (countries_data['Population_2']>300000000)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15640\2944914179.py in ?()
# ----> 1 countries_data[(countries_data['Region']=='Asia') or (countries_data['Population_2']>300000000)]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#****we have to use pipe symbol (|) for 'or'...typing 'or' will throw above error, lets do it again

# %%
countries_data[(countries_data['Region']=='Asia') | (countries_data['Population_2']>300000000)]
# Out:
#    Rank Country / Dependency    Region        Population % of world  \
# 0     1                China      Asia  1,412,600,000.00     17.80%
# 1     2                India      Asia  1,386,946,912.00     17.50%
# 2     3        United States  Americas    333,073,186.00      4.20%
# 3     4            Indonesia      Asia    271,350,000.00      3.42%
# 4     5             Pakistan      Asia    225,200,000.00      2.84%
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%
#
#         Date  Population_2
# 0  31-Dec-21    1412600000
# 1  18-Jan-22    1386946912
# 2  18-Jan-22     333073186
# 3  31-Dec-20     271350000
# 4   1-Jul-21     225200000
# 7  18-Jan-22     172062576

# %%
#fffff, it worked

# %%
#lets say if we only want the selected column from above results, then just stack it up like below:

# %%
countries_data[(countries_data['Region']=='Asia') | (countries_data['Population_2']>300000000)][['Rank', 'Region', 'Country / Dependency']]
# Out:
#    Rank    Region Country / Dependency
# 0     1      Asia                China
# 1     2      Asia                India
# 2     3  Americas        United States
# 3     4      Asia            Indonesia
# 4     5      Asia             Pakistan
# 7     8      Asia           Bangladesh

# %%
#so we got the info (require columns where -either we have region==asia OR population>300000000)

# %%
#head (first n records, by default 5 elements) & ...

#tail (last n records, by default 5 elements)

# %%
countries_data.head()    #got first 5 records
# Out:
#    Rank Country / Dependency    Region        Population % of world  \
# 0     1                China      Asia  1,412,600,000.00     17.80%
# 1     2                India      Asia  1,386,946,912.00     17.50%
# 2     3        United States  Americas    333,073,186.00      4.20%
# 3     4            Indonesia      Asia    271,350,000.00      3.42%
# 4     5             Pakistan      Asia    225,200,000.00      2.84%
#
#         Date  Population_2
# 0  31-Dec-21    1412600000
# 1  18-Jan-22    1386946912
# 2  18-Jan-22     333073186
# 3  31-Dec-20     271350000
# 4   1-Jul-21     225200000

# %%
countries_data.tail()        #got last 5 records
# Out:
#    Rank Country / Dependency    Region      Population % of world       Date  \
# 5     6               Brazil  Americas  214,231,641.00      2.70%  18-Jan-22
# 6     7              Nigeria    Africa  211,401,000.00      2.67%   1-Jul-21
# 7     8           Bangladesh      Asia  172,062,576.00      2.17%  18-Jan-22
# 8     9               Russia    Europe  146,171,015.00      1.84%   1-Jan-21
# 9    10               Mexico  Americas  126,014,024.00      1.59%   2-Mar-20
#
#    Population_2
# 5     214231641
# 6     211401000
# 7     172062576
# 8     146171015
# 9     126014024

# %%
countries_data.head(7)    #got first 7 records, as this time we specfied 7
# Out:
#    Rank Country / Dependency    Region        Population % of world  \
# 0     1                China      Asia  1,412,600,000.00     17.80%
# 1     2                India      Asia  1,386,946,912.00     17.50%
# 2     3        United States  Americas    333,073,186.00      4.20%
# 3     4            Indonesia      Asia    271,350,000.00      3.42%
# 4     5             Pakistan      Asia    225,200,000.00      2.84%
# 5     6               Brazil  Americas    214,231,641.00      2.70%
# 6     7              Nigeria    Africa    211,401,000.00      2.67%
#
#         Date  Population_2
# 0  31-Dec-21    1412600000
# 1  18-Jan-22    1386946912
# 2  18-Jan-22     333073186
# 3  31-Dec-20     271350000
# 4   1-Jul-21     225200000
# 5  18-Jan-22     214231641
# 6   1-Jul-21     211401000

# %%
#cool, lets see selecting data 2 (is in...in not in '`')..using tilda `

# %%
#lets say if we need to return the rows, where value in column is present in [list of values]

# %%
countries_data
# Out:
#    Rank Country / Dependency    Region        Population % of world  \
# 0     1                China      Asia  1,412,600,000.00     17.80%
# 1     2                India      Asia  1,386,946,912.00     17.50%
# 2     3        United States  Americas    333,073,186.00      4.20%
# 3     4            Indonesia      Asia    271,350,000.00      3.42%
# 4     5             Pakistan      Asia    225,200,000.00      2.84%
# 5     6               Brazil  Americas    214,231,641.00      2.70%
# 6     7              Nigeria    Africa    211,401,000.00      2.67%
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%
# 8     9               Russia    Europe    146,171,015.00      1.84%
# 9    10               Mexico  Americas    126,014,024.00      1.59%
#
#         Date  Population_2
# 0  31-Dec-21    1412600000
# 1  18-Jan-22    1386946912
# 2  18-Jan-22     333073186
# 3  31-Dec-20     271350000
# 4   1-Jul-21     225200000
# 5  18-Jan-22     214231641
# ...

# %%
#lets say if we need to find the rows, where region column has values [either Asia or Americas]

# %%
countries_data['Region'].isin(['Asia', 'Americas'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: Region, dtype: bool

# %%
#cool, lets pass this too the DF (countries_data)

# %%
countries_data[countries_data['Region'].isin(['Asia', 'Americas'])]
# Out:
#    Rank Country / Dependency    Region        Population % of world  \
# 0     1                China      Asia  1,412,600,000.00     17.80%
# 1     2                India      Asia  1,386,946,912.00     17.50%
# 2     3        United States  Americas    333,073,186.00      4.20%
# 3     4            Indonesia      Asia    271,350,000.00      3.42%
# 4     5             Pakistan      Asia    225,200,000.00      2.84%
# 5     6               Brazil  Americas    214,231,641.00      2.70%
# 7     8           Bangladesh      Asia    172,062,576.00      2.17%
# 9    10               Mexico  Americas    126,014,024.00      1.59%
#
#         Date  Population_2
# 0  31-Dec-21    1412600000
# 1  18-Jan-22    1386946912
# 2  18-Jan-22     333073186
# 3  31-Dec-20     271350000
# 4   1-Jul-21     225200000
# 5  18-Jan-22     214231641
# 7  18-Jan-22     172062576
# 9   2-Mar-20     126014024

# %%
#cool, this is how it works, now lets see - how to find out the rows where 'Region' is not in list

# simply insert (tilda '~') before the condition

# %%
~countries_data['Region'].isin(['Asia', 'Americas'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# Name: Region, dtype: bool

# %%
#you see the condition is reversed now, lets pass this to the DF(countries_data)

# %%
countries_data[~countries_data['Region'].isin(['Asia', 'Americas'])]
# Out:
#    Rank Country / Dependency  Region      Population % of world      Date  \
# 6     7              Nigeria  Africa  211,401,000.00      2.67%  1-Jul-21
# 8     9               Russia  Europe  146,171,015.00      1.84%  1-Jan-21
#
#    Population_2
# 6     211401000
# 8     146171015

# %%
#cool, lets move to another lecture...data manipulations
