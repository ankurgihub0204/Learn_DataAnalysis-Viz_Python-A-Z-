# %%
# Bar plots
# matplotlib.pyplot.bar(arguments) OR plt.bar(arguments)
# plt.bar(x, height, width, bottom, align, color, edgecolr etc)..read documents or this file

# matplotlib.pyplot.barh(arguments) OR plt.barh(arguments) ......for horizontal bars

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('top_10_countries.csv')

# %%
df.head()
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21

# %%
# if we want to plot a bar graph to show region(x-axis) & population(y axis); first we need to group region by population

#so, lets group region by population(sum)

# %%
df_g=df[['Region', 'Population']].groupby(by='Region').sum()

# %%
df_g
# Out:
#                                                  Population
# Region
# Africa                                       211,401,000.00
# Americas         333,073,186.00214,231,641.00126,014,024.00
# Asia      1,412,600,000.001,386,946,912.00271,350,000.00...
# Europe                                       146,171,015.00

# %%
#hmm, looks like population not adding up correctly, lets check the dtypes, may be its not integer

# %%
df.dtypes
# Out:
# Rank                     int64
# Country / Dependency    object
# Region                  object
# Population              object
# % of world              object
# Date                    object
# dtype: object

# %%
#oh ok, so lets change population to integer

#df['Column1'] = pd.to_numeric(df['Column1'], downcast='integer', errors='coerce')

# %%
df['Population']=pd.to_numeric(df['Population'],downcast='integer', errors='raise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,412,600,000.00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['Population']=pd.to_numeric(df['Population'],downcast='integer', errors='raise')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
# ...

# %%
df.dtypes
# Out:
# Rank                     int64
# Country / Dependency    object
# Region                  object
# Population              object
# % of world              object
# Date                    object
# dtype: object

# %%
df['Population']
# Out:
# 0    1,412,600,000.00
# 1    1,386,946,912.00
# 2      333,073,186.00
# 3      271,350,000.00
# 4      225,200,000.00
# 5      214,231,641.00
# 6      211,401,000.00
# 7      172,062,576.00
# 8      146,171,015.00
# 9      126,014,024.00
# Name: Population, dtype: object

# %%
#hmm, not working, lets use 'apply' method & strip ',' and end .00
#first lets check df

# %%
df.head()
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21

# %%
#oh, lets call the csv again, since population coloumn is messed up now :(

# %%
df=pd.read_csv('top_10_countries.csv')

# %%
df.head()
# Out:
#    Rank Country / Dependency    Region        Population % of world       Date
# 0     1                China      Asia  1,412,600,000.00     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,912.00     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,186.00      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,000.00      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,000.00      2.84%   1-Jul-21

# %%
df['Population']=df['Population'].apply(lambda x:x.replace('.00','0'))

# %%
df.head()
# Out:
#    Rank Country / Dependency    Region      Population % of world       Date
# 0     1                China      Asia  1,412,600,0000     17.80%  31-Dec-21
# 1     2                India      Asia  1,386,946,9120     17.50%  18-Jan-22
# 2     3        United States  Americas    333,073,1860      4.20%  18-Jan-22
# 3     4            Indonesia      Asia    271,350,0000      3.42%  31-Dec-20
# 4     5             Pakistan      Asia    225,200,0000      2.84%   1-Jul-21

# %%
#cool, now again apply 'apply' finction to remove ','

# %%
df['Population']=df['Population'].apply(lambda x:x.replace(',',''))

# %%
df.head()
# Out:
#    Rank Country / Dependency    Region   Population % of world       Date
# 0     1                China      Asia  14126000000     17.80%  31-Dec-21
# 1     2                India      Asia  13869469120     17.50%  18-Jan-22
# 2     3        United States  Americas   3330731860      4.20%  18-Jan-22
# 3     4            Indonesia      Asia   2713500000      3.42%  31-Dec-20
# 4     5             Pakistan      Asia   2252000000      2.84%   1-Jul-21

# %%
df.dtypes
# Out:
# Rank                     int64
# Country / Dependency    object
# Region                  object
# Population              object
# % of world              object
# Date                    object
# dtype: object

# %%
#now, lets change polulation to integer

# %%
df['Population']=df['Population'].astype('int64')

# %%
df.head()
# Out:
#    Rank Country / Dependency    Region   Population % of world       Date
# 0     1                China      Asia  14126000000     17.80%  31-Dec-21
# 1     2                India      Asia  13869469120     17.50%  18-Jan-22
# 2     3        United States  Americas   3330731860      4.20%  18-Jan-22
# 3     4            Indonesia      Asia   2713500000      3.42%  31-Dec-20
# 4     5             Pakistan      Asia   2252000000      2.84%   1-Jul-21

# %%
df.dtypes
# Out:
# Rank                     int64
# Country / Dependency    object
# Region                  object
# Population               int64
# % of world              object
# Date                    object
# dtype: object

# %%
#cool, finally able to reach first step to plot the graph, lets group by region and sum(population)

# %%
df_g=df[['Region', 'Population']].groupby(by='Region').sum()

# %%
df_g
# Out:
#            Population
# Region
# Africa     2114010000
# Americas   6733188510
# Asia      34681594880
# Europe     1461710150

# %%
#finally, reached this point (44sec of video), now we are ready to plot region vs population

# %%
fig, ax=plt.subplots(1,1)

# %%
fig, ax=plt.subplots(1,1, tight_layout=True)
ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Population by region')

ax.bar(df_g['Region'], df_g['Population'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 6
# ...

# %%
#lol, you know why it didn't work, coz region is set as index (holy molly), remember to reset_index in df_g DataFrame

# %%
#lets do it again

# %%
df_g
# Out:
#            Population
# Region
# Africa     2114010000
# Americas   6733188510
# Asia      34681594880
# Europe     1461710150

# %%
df_g=df_g.reset_index()

# %%
df_g
# Out:
#      Region   Population
# 0    Africa   2114010000
# 1  Americas   6733188510
# 2      Asia  34681594880
# 3    Europe   1461710150

# %%
#cool, so now 'x=Region', proper argument for bar, lets call fig, ax, subplot etc again...

# %%
#creating fig, ax objects:

fig, ax=plt.subplots(1,1, tight_layout=True)

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Population by region')
# Out:
# Text(0.5, 1.0, 'Population by region')

# %%
#creating fig, ax objects:

fig, ax=plt.subplots(1,1, tight_layout=True)

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')

#plotting the bar chart, 2 arguments passed (x, height)

ax.bar(x=df_g['Region'], height=df_g['Population'])
# Out:
# <BarContainer object of 4 artists>

# %%
#creating fig, ax objects:

fig, ax=plt.subplots(1,1, tight_layout=True)

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')

#plotting the bar chart, 2 arguments passed (x, height). We even dont have to call (x= or height=)...
#...simply provide the value for x & height

ax.bar(df_g['Region'], df_g['Population'])
# Out:
# <BarContainer object of 4 artists>

# %%
#if we dont want out[101] <BarContainer object of 4 artists> and all, simply use plt.show...

# %%
#creating fig, ax objects:

fig, ax=plt.subplots(1,1, tight_layout=True)

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')

#plotting the bar chart, 2 arguments passed (x, height). We even dont have to call (x= or height=)...
#...simply provide the value for x & height

ax.bar(df_g['Region'], df_g['Population'])

#using plt.show() toget rid of out[#]
plt.show()

# %%
#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')

#plotting the bar chart, 3 arguments passed (x, height, width=0.5)

ax.bar(df_g['Region'], df_g['Population'],width=0.5)

#using plt.show() toget rid of out[#]
plt.show()

# %%
#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color='grey', edgecolor='black')

ax.bar(df_g['Region'], df_g['Population'],width=0.5, color='grey', edgecolor='black')


#using plt.show() toget rid of out[#]
plt.show()

# %%
#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color='#5584AC', edgecolor='black')...
#..this time, for color, we used hex-code '#5584AC', hex-code can be found by googling


ax.bar(df_g['Region'], df_g['Population'],width=0.5, color='#5584AC', edgecolor='red')


#using plt.show() toget rid of out[#]
plt.show()

# %%
#to order bar from highest-->lowest; adjust df_g in that order by sorting it high-->low
#use sort_values(by='Population', ascending=False), then plot the graph again

# %%
df_g
# Out:
#      Region   Population
# 0    Africa   2114010000
# 1  Americas   6733188510
# 2      Asia  34681594880
# 3    Europe   1461710150

# %%
#lets sort it in descending (ascending=False) order

df_g.sort_values(by='Population', ascending=False, inplace=True)

# %%
df_g
# Out:
#      Region   Population
# 2      Asia  34681594880
# 1  Americas   6733188510
# 0    Africa   2114010000
# 3    Europe   1461710150

# %%
#now, if we plot the bar chart..

# %%
#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color='#5584AC', edgecolor='black')...
#..this time, for color, we used hex-code '#5584AC', hex-code can be found by googling


ax.bar(df_g['Region'], df_g['Population'],width=0.5, color='#5584AC', edgecolor='red')


#using plt.show() toget rid of out[#]
plt.show()

# %%
#lets make each bar a different color..

# %%
#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..provided the list of color, short name is good to go, b=blue, r=red etc
# this way each color goes to corresponding bar, e.e. 'b' will color the first bar as blue, and so on..

ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=['b','r','y','g'], edgecolor='red')


#using plt.show() toget rid of out[#]
plt.show()

# %%
#JLT, trying to see if we pass a list of color, in this way-- color=clr
clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..provided the list of color, short name is good to go, b=blue, r=red etc

ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red')


#using plt.show() toget rid of out[#]
plt.show()

# %%
#JLT, trying to see if we pass a list of color, in this way-- color=clr
clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..this time we will go for bar_label to show 'population value' for each bar

bar_c=ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red')
ax.bar_label(bar_c, label_type='edge', fontsize=10)


#using plt.show() toget rid of out[#]
plt.show()

# %%
#bar_label are not satifactory, we shd convert it in some readable format (thats where we use 'fmt' argument in lable)

# %%
#JLT, trying to see if we pass a list of color, in this way-- color=clr
clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..this time we will go for bar_label to show 'population value' for each bar

bar_c=ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red')

#formatting the bar label using lambda fn:
ax.bar_label(bar_c, label_type='edge', fontsize=10, fmt=lambda x:f'{round(x/1000000,0)} Mils')


#using plt.show() toget rid of out[#]
plt.show()

# %%
#wow, kind of master now, lets learn to set up legends too:...

# %%
#JLT, trying to see if we pass a list of color, in this way-- color=clr
clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..this time we will go for bar_label to show 'population value' for each bar

bar_c=ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red')

#formatting the bar label using lambda fn:
ax.bar_label(bar_c, label_type='edge', fontsize=10, fmt=lambda x:f'{round(x/1000000,0)} Mils')

#setting up,bar_legend ax.legend(title='Fruit color', frameon=False, loc='lower center', ncol=2)

ax.legend(df_g['Region'],title='Continents', loc='upper center', ncol=4, fontsize="10")
#ax.legend()



#using plt.show() toget rid of out[#]
plt.show()

# %%
#hmm, not all legends flows in, only asia is being picked, may be we need to pass a list of region, lets try..

#actually tried and this worked ...yay!!

# %%
lgnd=[]
for x in df_g['Region']:
    lgnd.append(x)

# %%
lgnd
# Out:
# ['Asia', 'Americas', 'Africa', 'Europe']

# %%
#JLT, trying to see if we pass a list of color, in this way-- color=clr
clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..this time we will go for bar_label to show 'population value' for each bar

bar_c=ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red', label=df_g['Region'])

#formatting the bar label using lambda fn:
ax.bar_label(bar_c, label_type='edge', fontsize=10, fmt=lambda x:f'{round(x/1000000,0)} Mils')

#setting up,bar_legend ax.legend(title='Fruit color', frameon=False, loc='lower center', ncol=2)

#ax.legend(lgnd,title='Continents', loc='upper center', ncol=4, fontsize="10")
ax.legend()


#using plt.show() toget rid of out[#]
plt.show()

# %%
#JLT, trying to see if we pass a list of color, in this way-- color=clr
clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..this time we will go for bar_label to show 'population value' for each bar

bar_c=ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red', label=df_g['Region'])

#formatting the bar label using lambda fn:
ax.bar_label(bar_c, label_type='edge', fontsize=10, fmt=lambda x:f'{round(x/1000000,0)} Mils')

#ax.legend()

#lets format the legend with some arguments --> ax.legend(title='Fruit color', frameon=False, loc='lower center', ncol=2)

ax.legend(title='Continents', loc='upper center', ncol=4, fontsize="10")

#using plt.show() toget rid of out[#]
plt.show()

# %%
#cool, it worked, lets play along little more:

clr=['g','y','b','r']

#creating fig, ax objects, this time figsize=(8,5)

fig, ax=plt.subplots(1,1, tight_layout=True, figsize=(8,5))

#setting ax attributes:

ax.set_xlabel('Regions')
ax.set_ylabel('Population')
ax.set_title('Top Regions by population')

#plotting the bar chart, 5 arguments passed (x, height, width=0.8, color=['b','r','y','g'], edgecolor='black')...
#..this time we will go for bar_label to show 'population value' for each bar

bar_c=ax.bar(df_g['Region'], df_g['Population'],width=0.5, color=clr, edgecolor='red', label=df_g['Region'])

#formatting the bar label using lambda fn:
ax.bar_label(bar_c, label_type='edge', fontsize=10, fmt=lambda x:f'{round(x/1000000,0)} Mils')

#ax.legend()

#lets format the legend with some arguments --> ax.legend(title='Fruit color', frameon=False, loc='lower center', ncol=2)

ax.legend(title='Continents', loc='upper right', ncol=2, fontsize="8")

#using plt.show() toget rid of out[#]
plt.show()

# %%
#hmm, cool stuff. So far legeng to work, first pass label=df['Region'] or any DF column

# %%
# note here: we are skipping stacked bar in this lecture, which we will cover in sea born library, as its much easier there

# or actually, we will follow along a youtube video, and learn how to create stacked(top) or staked(side by side) bar charts

# %%
#lets quickly see horizontal bar chart..(ax.barh)

#drawing above chart as horizontal graph...

# %%
#1st lets call a figure, ax
fig, ax=plt.subplots(figsize=(10,5), tight_layout=True)

#lets set axis name, chart name etc:

ax.set_xlabel('Population(in Millions)')
ax.set_ylabel('Region')
ax.set_title('Population by Region BAR-H')



# clr=['g','y','b','r'] is created in above lines of code, label will help in legend call, ax.legend()

ax.barh(y=df_g['Region'], width=df_g['Population'], color=clr, label=df_g['Region'])
# Out:
# <BarContainer object of 4 artists>

# %%
#1st lets call a figure, ax
fig, ax=plt.subplots(figsize=(15,8), tight_layout=True)

#lets set axis name, chart name etc; this time in a different way, all set in one:

ax.set(xlabel='Population(in Mils)', ylabel='Region', title='Population by Region BAR-H-R')


# clr=['g','y','b','r'] is created in above lines of code, bar_ch is created to be assigned  as argument in bar_label...
#... label will help in legend call, ax.legend()

bar_ch=ax.barh(y=df_g['Region'], width=df_g['Population'], color=clr, height= 0.8, label=df_g['Region'])

#set up bar_label

ax.bar_label(bar_ch, label_type='edge', fontsize=12, fmt=lambda x: f'{x/100000} Mils')

#Finally plt.show() to show the proper chart

plt.show()

# %%
#hmm, title/lable etc fonts looks too smaller, lets set them little larger

# %%
#1st lets call a figure, ax
fig, ax=plt.subplots(figsize=(18,8), tight_layout=True)

#lets set axis name, chart name etc; this time in a different way, all set in one:

ax.set_xlabel('Population(in Mils)', fontsize=15)
ax.set_ylabel('Region', fontsize=15)
ax.set_title('Population by Region BAR-H-R', fontsize=20)


# clr=['g','y','b','r'] is created in above lines of code, bar_ch is created to be assigned  as argument in bar_label...
#... label will help in legend call, ax.legend()

bar_ch=ax.barh(y=df_g['Region'], width=df_g['Population'], color=clr, height= 0.8, label=df_g['Region'])

#set up bar_label

ax.bar_label(bar_ch, label_type='edge', fontsize=15, fmt=lambda x: f'{x/100000} Mils')

#show legend

ax.legend(title='Continents', fontsize=18, ncols=2)


#Finally plt.show() to show the proper chart

plt.show()

# %%
#you see here the probelme is word 'continent is too small', to make it large, do as below:

# %%
#1st lets call a figure, ax
fig, ax=plt.subplots(figsize=(18,8), tight_layout=True)

#lets set axis name, chart name etc; this time in a different way, all set in one:

ax.set_xlabel('Population(in Mils)', fontsize=15)
ax.set_ylabel('Region', fontsize=15)
ax.set_title('Population by Region BAR-H-R', fontsize=20)


# clr=['g','y','b','r'] is created in above lines of code, bar_ch is created to be assigned  as argument in bar_label...
#... label will help in legend call, ax.legend()

bar_ch=ax.barh(y=df_g['Region'], width=df_g['Population'], color=clr, height= 0.8, label=df_g['Region'])

#set up bar_label

ax.bar_label(bar_ch, label_type='edge', fontsize=15, fmt=lambda x: f'{x/100000} Mils')

#show legend
#also, fix for the word 'continent' to make it large, do as below:

legend=ax.legend(title='Continents', fontsize=18, ncols=2)
plt.setp(legend.get_title(),fontsize=20)

#Finally plt.show() to show the proper chart

plt.show()

# %%
#cool, other problem is x/y axis ticks (population/region values) are too small, lets see

# %%
#1st lets call a figure, ax
fig, ax=plt.subplots(figsize=(18,8), tight_layout=True)

#lets set axis name, chart name etc; this time in a different way, all set in one:

ax.set_xlabel('Population(in Mils)', fontsize=15)
ax.set_ylabel('Region', fontsize=15)
ax.set_title('Population by Region BAR-H-R', fontsize=20)


# clr=['g','y','b','r'] is created in above lines of code, bar_ch is created to be assigned  as argument in bar_label...
#... label will help in legend call, ax.legend()

bar_ch=ax.barh(y=df_g['Region'], width=df_g['Population'], color=clr, height= 0.8, label=df_g['Region'])

#set up bar_label

ax.bar_label(bar_ch, label_type='edge', fontsize=15, fmt=lambda x: f'{round(x/100000,0)} Mils')

#show legend
#also, fix for the word 'continent' to make it large, do as below:

legend=ax.legend(title='Continents', fontsize=18, ncols=2)
plt.setp(legend.get_title(),fontsize=20)

#font size for x-ticks/y-ticks:

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)


#Finally plt.show() to show the proper chart

plt.show()

# %%
#cool, this works...we can learn more & more later, so lets move on to you tube video lecture for....
#...multiple bar charts and stacked bars charts

# %%
#youtube link:

#https://www.youtube.com/watch?v=9VK8quGFcSE&list=PLH8OzCI4-B7jLH3xW-uQWqhekMjNLLH7k&index=21&t=591s

#other links:

#matplotlib-style-link:
#https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

#matplotlib-color-link:
#https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
import numpy as np
# %matplotlib inline
from matplotlib import style

# %%
#lets say we have a data about time spend on ariuos social media app

social_time_data = {'facebook':120, 'youtube':90, 'instagram':40, 'snapchat':28}

# %%
#lets convert it in x&y (social_media & time_spend) data

# %%
social_time_data.keys()
# Out:
# dict_keys(['facebook', 'youtube', 'instagram', 'snapchat'])

# %%
social_media=list(social_time_data.keys())

# %%
social_media
# Out:
# ['facebook', 'youtube', 'instagram', 'snapchat']

# %%
time_spend=list(social_time_data.values())

# %%
time_spend
# Out:
# [120, 90, 40, 28]

# %%
#cool so far, lets draw a simple single bar chart out of it, by youtube method:

# %%
plt.bar(social_media, time_spend, color='lightcoral', width=0.5) #used matplotlib color page for reference: https://matplotlib.org/stable/gallery/color/named_colors.html
# Out:
# <BarContainer object of 4 artists>

# %%
#lets change the figsize, and add title, x&y label..and style

# %%
style.use('dark_background') #referd to matplotlib's style reference page: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.figure(figsize=(5,5))
plt.bar(social_media, time_spend, color='khaki', width=0.5)
plt.xlabel('Social Media') #note its not plt.set_xlabel, no such attribute exist for plt
plt.ylabel('Time in Minutes')
plt.title('Average Time Spend 0n Social Media')
# Out:
# Text(0.5, 1.0, 'Average Time Spend 0n Social Media')

# %%
#lets use different color for each bar...so lets first set the color variable

color=['rosybrown', 'goldenrod', 'tab:brown', 'forestgreen']

# %%
style.use('dark_background') #referd to matplotlib's style reference page: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.figure(figsize=(5,5))
plt.bar(social_media, time_spend, color=color, width=0.5)
plt.xlabel('Social Media', fontsize=10) #note its not plt.set_xlabel, no such attribute exist for plt
plt.ylabel('Time in Minutes', fontsize=10)
plt.title('Average Time Spend 0n Social Media', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Average Time Spend 0n Social Media')

# %%
#now, lets move on to how to create multiple bar charts (something like bar chart showing sales 'by region by territory')

# %%
#first, lets create some data for it, lets create it for facebook, youtube, instagram & snapchat (#fb,yt,ig,sc)

fb = (120, 90, 110, 100, 95)
yt = (80, 90, 75, 85, 95)
ig = (50, 40, 55, 35, 45)
sc = (20, 30, 35, 25, 28)

# %%
#now, see, we need to define some datapoints on x-axis for each data above, so lets do it using nparray

xpos=np.arange(len(fb))

# %%
xpos
# Out:
# array([0, 1, 2, 3, 4])

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))

#first plotting fb:
plt.bar(xpos, fb, color='royalblue', width=0.2, label='FB')

#setting overall chart properties etc:

plt.xlabel('Social Media', fontsize=10)
plt.ylabel('Time in Minutes', fontsize=10)
plt.title('Average Time Spend 0n Social Media')
# Out:
# Text(0.5, 1.0, 'Average Time Spend 0n Social Media')

# %%
#now, similarly, lets plot for youtube:

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))

#first plotting fb:
plt.bar(xpos, fb, color='royalblue', width=0.2, label='FB')

#second plotting for yt:
plt.bar(xpos+0.2, yt, color='red', width=0.2, label='YT') #here we did xpos+0.2, so 2nd bar offsets by 0.2, and stand next to fb's bar


#setting overall chart properties etc:

plt.xlabel('Day')
plt.ylabel('Time spend in Minutes')
plt.title('Average Time Spend on Social Media')
plt.legend()

# %%
#WOW, Lets add other ig and sc bar too...

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))

#first plotting fb:
plt.bar(xpos, fb, color='royalblue', width=0.2, label='FB')

#second plotting for yt:
plt.bar(xpos+0.2, yt, color='red', width=0.2, label='YT') #here we did xpos+0.2, so 2nd bar offsets by 0.2, and stand next to fb's bar

#third plotting ig:
plt.bar(xpos+0.4, ig, color='purple', width=0.2, label='IG')

#fourth, final bar for plotting sc:
plt.bar(xpos+0.6, sc, color='yellow', width=0.2, label='SC')

#setting overall chart properties etc:

plt.xlabel('Day')
plt.ylabel('Time spend in Minutes')
plt.title('Average Time Spend on Social Media')
plt.legend()

# %%
#using xticks to clean the values on x-axis

#also, lets fix the legend and title, as they are not visible

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))

#first plotting fb:
plt.bar(xpos, fb, color='royalblue', width=0.2, label='FB')

#second plotting for yt:
plt.bar(xpos+0.2, yt, color='red', width=0.2, label='YT') #here we did xpos+0.2, so 2nd bar offsets by 0.2, and stand next to fb's bar

#third plotting ig:
plt.bar(xpos+0.4, ig, color='purple', width=0.2, label='IG')

#fourth, final bar for plotting sc:
plt.bar(xpos+0.6, sc, color='yellow', width=0.2, label='SC')

#setting overall chart properties etc:

plt.xlabel('Day')
plt.ylabel('Time spend in Minutes')
plt.title('Average Time Spend on Social Media', loc='left', color='k') # title is visible now
plt.legend(title='Social Media', ncols=4, facecolor='k') # legend is visible now

#using xticks to clean the values on x-axis
plt.xticks(xpos+0.3, ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'))

#finally show
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#cool, its fixed and better looking now..we will revisit it later for bar_label

#for now, lets stack it up...lets see how to create a stacked bar chart out of this....

# %%
#for stacked chart, we just have to keep the 'xpos' same, but only add bottom argument with plt.bar...
# value for bottom argumnet will be first bar value i.e start the bar where previous bar ended from bottom

# lets see.. lets do it with 2 bars first (fb & yt), then we will stack up more ;)

# %%
#since restarting from last session after break, lets recall numpy,plt and all..

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from matplotlib import style

# %%
#defining some variable that we will use it in plotting

xticks_val = ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday')

xpos = np.arange(0,5,1)

fb = (120, 90, 110, 100, 95)
yt = (80, 90, 75, 85, 95)

#ig = (50, 40, 55, 35, 45)
#sc = (20, 30, 35, 25, 28)

#plotting

fig=plt.figure(figsize=(10,8))

fb_bar1 = plt.bar(xpos, fb, color='blue', width=0.4, label='FB')

#stacking 'yt_bar2' on to of 'fb_bar1' bar

yt_bar2 = plt.bar(xpos, yt, bottom=fb, color='red', width=0.4, label='YT') #note bottom argument

plt.xticks(xpos, xtick_val)

#finally plt.show()
plt.show()

# %%
#COOL STUFF, so practice done, lets stack the other 2 bars (ig & sc) too

# %%
#defining some variable that we will use it in plotting

xticks_val = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
xpos = np.arange(len(xticks_val))
fb = (120, 90, 110, 100, 95)
yt = (80, 90, 75, 85, 95)
ig = (50, 40, 55, 35, 45)
sc = (20, 30, 35, 25, 28)

#plotting figure object

fig=plt.figure(figsize=(10,7))

#bar1 for fb

fb_bar1= plt.bar(xpos, fb, color='blue', width=0.4, label='FB')
plt.bar_label(fb_bar1, label_type='edge', color='white', fontsize=10) #display bar_label,fb_bar1

#stacking 'yt_bar2' on to of 'fb_bar1' bar

yt_bar2= plt.bar(xpos, yt, bottom=fb, color='red', width=0.4, label='YT') #note bottom argument
plt.bar_label(yt_bar2, label_type='edge', color='k', fontsize=10) #display bar_label,fb_bar1

#stacking 'yt_bar2' on to of 'fb_bar1' bar

ig_bar3 = plt.bar(xpos, ig, bottom=fb, color='purple', width=0.4, label='IG') #note bottom argument
plt.bar_label(ig_bar3, label_type='edge', color='k', fontsize=10) #display bar_label,fb_bar1


#stacking 'yt_bar2' on to of 'fb_bar1' bar
#sc_bar4
#plt.bar(xpos, sc, bottom=ig, color='yellow', width=0.4, label='SC') #note bottom argument

#xticks
plt.xticks(xpos, xtick_val)

#finally plt.show()
plt.show()

# %%
#well, above bar is not proper on y-axs, still will take it as some learning..we shall see it in seaborn, or else....
#...will revisit here

#xlabel, ylabel, title are deliberately left blank

# %%
#also, leaving horizontal stacked bar charts here, coz again, will wait for seaborn sns

#lets move to line chrt in next lecture
